# %% [markdown]
# ## Writing Prompt
#
# ### What are your goals for this course?
#
# My main goal for this course is to improve my Python programming and data analysis skills by working with real astronomical data. I also want to better understand how astronomers detect and study exoplanets. I hope this course will give me more experience in scientific research and help me prepare for future research opportunities.
#
# ### What topics in astronomy interest you?
#
# I am especially interested in Mars and its exploration because I am curious about its geology, climate, and the possibility that it may have supported life in the past. I also enjoy learning about exoplanets and how scientists search for potentially habitable worlds. I find it fascinating how new space missions and telescopes help us better understand our universe.
