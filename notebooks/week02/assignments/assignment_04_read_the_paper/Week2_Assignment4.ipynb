# %% [markdown]
# # Assignment 4 – Exoplanets Review

# %% [markdown]
# ## Questions from the Paper
#
# 1. Why is it necessary to combine the transit and radial velocity methods?
# 2. How can astronomers distinguish planetary signals from stellar activity?
# 3. Which future mission is expected to improve the detection of Earth-like planets the most?

# %% [markdown]
# ## Discord
#
# Why is it necessary to combine the transit and radial velocity methods to accurately determine an exoplanet's properties?
#
# _(Since Discord is blocked in my country, I'm asking my question here instead.)_
