# %% [markdown]
# # _Programming with Python_

# %% [markdown]
# ## _Python Fundamentals_

# %%
mass = 47.5
age = 122
mass = mass * 2.0
age = age - 20

# %%
print(mass)
# Out:
# 95.0

# %%
print(age)
# Out:
# 102

# %%
first, second = 'Grace', 'Hopper'
third, fourth = second, first
print(third, fourth)
# Out:
# Hopper Grace

# %%
planet = 'Earth'
apples = 5
distance = 10.5

# %%
print(planet)
# Out:
# Earth

# %%
print(apples)
# Out:
# 5

# %%
print(distance)
# Out:
# 10.5

# %%
# Integer
age = 20

# Float
weight = 60.3

# String
name = "Iclal"

print(age)
print(weight)
print(name)

print(type(age))
print(type(weight))
print(type(name))
# Out:
# 20
# 60.3
# Iclal
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
weight_lb = weight * 2.2

print(weight_lb)
# Out:
# 132.66

# %%
weight = 80

print(weight)
print(weight_lb)
# Out:
# 80
# 132.66

# %% [markdown]
# ## _Analyzing Patient Data_
